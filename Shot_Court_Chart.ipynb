# %%
#code taken from http://savvastjortjoglou.com/nba-shot-sharts.html
# %matplotlib inline
import requests
import matplotlib.pyplot as plt
import pandas as pd
#import seaborn as sns

nba_df= pd.read_csv("Resources/Final_nba_df.csv")

# %%
with pd.option_context('display.max_columns', None):
    display(nba_df.head())
# Out:
#     GAME_ID  W  FINAL_MARGIN  SHOT_NUMBER  PERIOD GAME_CLOCK  SHOT_CLOCK  \
# 0  21400899  W            24            1       1       1:09        10.8
# 1  21400899  W            24            2       1       0:14         3.4
# 2  21400899  W            24            3       1       0:00         NaN
# 3  21400899  W            24            4       2      11:47        10.3
# 4  21400899  W            24            5       2      10:34        10.9
#
#    SHOT_DIST  PTS_TYPE SHOT_RESULT   CLOSEST_DEFENDER  \
# 0        7.7         2        made     Anderson, Alan
# 1       28.2         3      missed  Bogdanovic, Bojan
# 2       10.1         2      missed  Bogdanovic, Bojan
# 3       17.2         2      missed      Brown, Markel
# 4        3.7         2      missed    Young, Thaddeus
#
#    CLOSEST_DEFENDER_PLAYER_ID  CLOSE_DEF_DIST  FGM  PTS    player_name  \
# 0                      101187             1.3    1    2  brian roberts
# 1                      202711             6.1    0    0  brian roberts
# 2                      202711             0.9    0    0  brian roberts
# 3                      203900             3.4    0    0  brian roberts
# 4                      201152             1.1    0    0  brian roberts
#
#    player_id
# 0     203148
# 1     203148
# 2     203148
# 3     203148
# 4     203148
